# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

from scipy import stats

# %%
league = {'brasileirao_a': ['Brasileirao'],
          'premier_league': ['Premier_League'],}


liga = league['brasileirao_a'][0]

# %%
historico = pd.read_excel(f'../datasets/{liga}/match_history/all_games/historico-2015a2023.xlsx')
rodadas = pd.read_excel(f'../datasets/{liga}/rounds/all_rounds/rodadas.xlsx')
tabela = pd.read_excel(f'../datasets/{liga}/standings/all_standings/season-2023/tabela-rodada29.xlsx')
#tabela = pd.read_excel(f'../datasets/{liga}/standings/all_standings/season-2023/tabela-rodada10.xlsx')

# %%
historico['date'] = pd.to_datetime(historico['date'], format='%Y-%m-%d')
historico['days'] = (max(historico['date']) - historico['date']).dt.days
historico['time_diff'] = np.exp(-0.001*historico['days'])

# %%
historico = historico[historico['season'] == 2023]

# %%
train = historico[historico['date'] < '2023-10-01'].dropna()
test = rodadas[rodadas['wk'] > 24].dropna()

#train = historico[historico['date'] < '2023-09-15'].dropna()
#test = rodadas[rodadas['wk'] > 4].dropna()

# %%
class Modelagem:
  # Fit no modelo
  def __init__(self, formula, data, max_goals= 5, output= None):
    self.modelo = smf.glm(formula= formula, data= data, family= sm.families.Poisson()).fit()
    #self.modelo = smf.glm(formula= formula, data= data, family= sm.families.NegativeBinomial()).fit()
    self.max_goals = max_goals
    if output is not None:
      print(self.modelo.summary())

  # Gerar Lambda
  def lambd(self, team, opponent, venue, stat, fator_casa= None):
    if fator_casa is True:
      string = 'casa' if venue == 'Home' else 'fora'
    else:
      string = 'total'

    data = {
        'team': team,
        'opponent': opponent,
        'venue': venue,
        'xg': float(stat[f'xg_{string}']),
        'xga': float(stat[f'xga_{string}']),
        'poss': float(stat[f'poss_{string}']),
        'sot': float(stat[f'sot_{string}']),
        'sh': float(stat[f'sh_{string}']),
        'time_diff': 1
    }
    return self.modelo.predict(pd.DataFrame(data, index=[0])).values[0]

  # Matriz de gols
  def matrix(self, lambda_x, lambda_y):
    prob_x = [stats.poisson.pmf(i, lambda_x) for i in range(0, self.max_goals+1)]
    prob_y = [stats.poisson.pmf(i, lambda_y) for i in range(0, self.max_goals+1)]

    return np.outer(prob_x, prob_y)
  
  # Função Final de Previsao de rodadas
  def predict_scores(self, matches, stats):
    for index, match in matches.iterrows():
      lambda_x = self.lambd(match['home'], match['away'], 'Home', stats.loc[stats['squad'] == match['home']], fator_casa= True)
      lambda_y = self.lambd(match['away'], match['home'], 'Away', stats.loc[stats['squad'] == match['away']], fator_casa= True)
      matrix_scores = self.matrix(lambda_x, lambda_y)
      
      matches.loc[index, 'vit_casa'] = np.sum(np.tril(matrix_scores, -1))
      matches.loc[index, 'empate'] = np.sum(np.diag(matrix_scores))
      matches.loc[index, 'vit_fora'] = np.sum(np.triu(matrix_scores, 1))
    
    return matches[['wk','xg_casa','xg_fora','home','gols_casa','gols_fora','away','vit_casa','empate','vit_fora']]
  
  # Teste acuracia
  def accuracy_score(self, matches):
    for index, match in matches.iterrows():
      #Gols
      if match['gols_casa'] > match['gols_fora']:
        matches.loc[index, 'resultado1'] = 'casa'
      elif match['gols_fora'] > match['gols_casa']:
        matches.loc[index, 'resultado1'] = 'fora'
      else:
        matches.loc[index, 'resultado1'] = 'empate'
      
      #Probabilidade
      if match['vit_casa'] > match['vit_fora'] and match['vit_casa'] > match['empate']:
        matches.loc[index, 'resultado2'] = 'casa'
      elif match['vit_fora'] > match['vit_casa'] and match['vit_fora'] > match['empate']:
        matches.loc[index, 'resultado2'] = 'fora'
      else:
        matches.loc[index, 'resultado2'] = 'empate'

    #Conclusao
    for index, match in matches.iterrows():
      if match['resultado1'] == match['resultado2']:
        matches.loc[index, 'resultado'] = 'acerto'
      else:
        matches.loc[index, 'resultado'] = 'fracasso'

    matches = matches.drop(['resultado1', 'resultado2'], axis= 1)
    score = matches['resultado'].value_counts()['acerto']/len(matches['resultado'])

    return matches, score

# %%
train.columns
# Out:
# Index(['date', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'sh', 'sot', 'season', 'team', 'days',
#        'time_diff'],
#       dtype='object')

# %%
#model = Modelagem(formula= 'gf ~ team*venue*poss*xg*sh + time_diff + opponent', data= train) #
model = Modelagem(formula= 'gf ~ team*xg*venue + opponent', data= train, output= True) #
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                     gf   No. Observations:                  490
# Model:                            GLM   Df Residuals:                      391
# Model Family:                 Poisson   Df Model:                           98
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -575.12
# Date:                Tue, 31 Oct 2023   Deviance:                       337.87
# Time:                        18:26:49   Pearson chi2:                     286.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.3928
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -0.1157      0.688     -0.168      0.867      -1.465       1.233
# team[T.ath_paranaense]                     -0.5403      0.975     -0.554      0.579      -2.451       1.371
# team[T.atl_mineiro]                        -0.9555      0.934     -1.023      0.306      -2.787       0.875
# team[T.bahia]                              -1.1596      0.944     -1.228      0.220      -3.011       0.691
# team[T.botafogo_rj]                        -0.7147      0.990     -0.722      0.470      -2.655       1.226
# team[T.bragantino]                         -0.6552      1.051     -0.624      0.533      -2.714       1.404
# team[T.corinthians]                         0.1627      0.967      0.168      0.866      -1.732       2.057
# team[T.coritiba]                            0.5075      1.082      0.469      0.639      -1.612       2.627
# team[T.cruzeiro]                           -0.6431      0.933     -0.689      0.491      -2.472       1.185
# team[T.cuiaba]                             -0.3766      1.343     -0.280      0.779      -3.010       2.256
# team[T.flamengo]                           -0.0524      0.910     -0.058      0.954      -1.835       1.730
# team[T.fluminense]                         -0.4406      0.906     -0.487      0.627      -2.215       1.334
# team[T.fortaleza]                          -0.9361      1.037     -0.903      0.366      -2.968       1.096
# team[T.goias]                              -0.5547      0.941     -0.589      0.556      -2.400       1.291
# team[T.gremio]                              0.5040      0.850      0.593      0.553      -1.162       2.170
# team[T.internacional]                      -1.7528      1.310     -1.338      0.181      -4.320       0.814
# team[T.palmeiras]                          -0.7112      0.954     -0.746      0.456      -2.580       1.158
# team[T.santos]                             -1.8259      1.131     -1.615      0.106      -4.042       0.390
# team[T.sao_paulo]                          -0.7464      1.406     -0.531      0.596      -3.503       2.010
# team[T.vasco_da_gama]                      -0.7460      1.141     -0.654      0.513      -2.983       1.491
# venue[T.Home]                              -0.3639      1.588     -0.229      0.819      -3.477       2.749
# opponent[T.ath_paranaense]                 -0.3341      0.257     -1.301      0.193      -0.837       0.169
# opponent[T.atl_mineiro]                    -0.6350      0.292     -2.172      0.030      -1.208      -0.062
# opponent[T.bahia]                          -0.3700      0.244     -1.520      0.129      -0.847       0.107
# opponent[T.botafogo_rj]                    -0.9961      0.317     -3.141      0.002      -1.618      -0.375
# opponent[T.bragantino]                     -0.5573      0.274     -2.030      0.042      -1.095      -0.019
# opponent[T.corinthians]                    -0.2401      0.251     -0.955      0.340      -0.733       0.253
# opponent[T.coritiba]                       -0.0450      0.240     -0.188      0.851      -0.515       0.425
# opponent[T.cruzeiro]                       -0.5570      0.279     -1.997      0.046      -1.104      -0.010
# opponent[T.cuiaba]                         -0.3543      0.264     -1.342      0.180      -0.872       0.163
# opponent[T.flamengo]                       -0.6247      0.273     -2.289      0.022      -1.160      -0.090
# opponent[T.fluminense]                     -0.3550      0.268     -1.326      0.185      -0.880       0.170
# opponent[T.fortaleza]                      -0.4062      0.269     -1.508      0.131      -0.934       0.122
# opponent[T.goias]                          -0.4232      0.262     -1.615      0.106      -0.937       0.090
# opponent[T.gremio]                         -0.2852      0.249     -1.146      0.252      -0.773       0.203
# opponent[T.internacional]                  -0.3579      0.248     -1.444      0.149      -0.844       0.128
# opponent[T.palmeiras]                      -0.5843      0.299     -1.955      0.051      -1.170       0.001
# opponent[T.santos]                          0.0233      0.235      0.099      0.921      -0.438       0.484
# opponent[T.sao_paulo]                      -0.3128      0.258     -1.213      0.225      -0.818       0.193
# opponent[T.vasco_da_gama]                  -0.0868      0.239     -0.364      0.716      -0.555       0.381
# team[T.ath_paranaense]:venue[T.Home]        1.9314      1.801      1.073      0.283      -1.598       5.461
# team[T.atl_mineiro]:venue[T.Home]           1.4131      1.984      0.712      0.476      -2.476       5.302
# team[T.bahia]:venue[T.Home]                 2.0020      1.987      1.008      0.314      -1.892       5.896
# team[T.botafogo_rj]:venue[T.Home]           2.2018      1.823      1.208      0.227      -1.372       5.775
# team[T.bragantino]:venue[T.Home]            0.3101      1.912      0.162      0.871      -3.438       4.058
# team[T.corinthians]:venue[T.Home]           0.0269      1.876      0.014      0.989      -3.650       3.704
# team[T.coritiba]:venue[T.Home]             -1.4134      2.029     -0.697      0.486      -5.389       2.563
# team[T.cruzeiro]:venue[T.Home]             -0.0917      2.246     -0.041      0.967      -4.493       4.310
# team[T.cuiaba]:venue[T.Home]                0.3868      2.114      0.183      0.855      -3.757       4.530
# team[T.flamengo]:venue[T.Home]              0.2957      1.837      0.161      0.872      -3.305       3.897
# team[T.fluminense]:venue[T.Home]            1.6752      1.773      0.945      0.345      -1.800       5.150
# team[T.fortaleza]:venue[T.Home]             1.2208      1.844      0.662      0.508      -2.394       4.835
# team[T.goias]:venue[T.Home]                 0.0476      1.923      0.025      0.980      -3.721       3.817
# team[T.gremio]:venue[T.Home]                0.3943      1.726      0.229      0.819      -2.988       3.777
# team[T.internacional]:venue[T.Home]         2.2823      2.154      1.059      0.289      -1.940       6.505
# team[T.palmeiras]:venue[T.Home]             1.4730      1.801      0.818      0.414      -2.058       5.003
# team[T.santos]:venue[T.Home]                0.9774      2.047      0.477      0.633      -3.035       4.990
# team[T.sao_paulo]:venue[T.Home]             1.1660      2.106      0.554      0.580      -2.961       5.293
# team[T.vasco_da_gama]:venue[T.Home]         0.5182      1.970      0.263      0.792      -3.343       4.379
# xg                                          0.4971      0.428      1.161      0.246      -0.342       1.337
# team[T.ath_paranaense]:xg                   0.4836      0.659      0.734      0.463      -0.808       1.775
# team[T.atl_mineiro]:xg                      0.5328      0.557      0.957      0.339      -0.559       1.624
# team[T.bahia]:xg                            0.2029      0.499      0.407      0.684      -0.775       1.181
# team[T.botafogo_rj]:xg                      0.7197      0.729      0.987      0.324      -0.709       2.149
# team[T.bragantino]:xg                       0.4917      0.688      0.715      0.475      -0.856       1.840
# team[T.corinthians]:xg                     -0.3845      0.904     -0.425      0.671      -2.157       1.388
# team[T.coritiba]:xg                        -0.4770      1.128     -0.423      0.672      -2.687       1.733
# team[T.cruzeiro]:xg                         0.4255      0.543      0.784      0.433      -0.638       1.489
# team[T.cuiaba]:xg                           0.0680      1.354      0.050      0.960      -2.585       2.721
# team[T.flamengo]:xg                         0.2474      0.593      0.417      0.677      -0.915       1.410
# team[T.fluminense]:xg                       0.0923      0.510      0.181      0.856      -0.907       1.091
# team[T.fortaleza]:xg                        0.3691      0.620      0.595      0.552      -0.846       1.584
# team[T.goias]:xg                            0.2280      0.674      0.338      0.735      -1.093       1.549
# team[T.gremio]:xg                          -0.3950      0.560     -0.705      0.481      -1.493       0.703
# team[T.internacional]:xg                    1.2447      1.058      1.177      0.239      -0.828       3.317
# team[T.palmeiras]:xg                        0.7637      0.653      1.169      0.242      -0.517       2.044
# team[T.santos]:xg                           0.6787      0.668      1.016      0.310      -0.631       1.988
# team[T.sao_paulo]:xg                        0.2960      1.080      0.274      0.784      -1.821       2.413
# team[T.vasco_da_gama]:xg                    0.5786      0.872      0.663      0.507      -1.131       2.288
# xg:venue[T.Home]                            0.0978      1.103      0.089      0.929      -2.064       2.259
# team[T.ath_paranaense]:xg:venue[T.Home]    -1.0097      1.231     -0.820      0.412      -3.423       1.403
# team[T.atl_mineiro]:xg:venue[T.Home]       -0.7158      1.332     -0.537      0.591      -3.327       1.895
# team[T.bahia]:xg:venue[T.Home]             -0.4922      1.291     -0.381      0.703      -3.023       2.039
# team[T.botafogo_rj]:xg:venue[T.Home]       -1.2523      1.275     -0.982      0.326      -3.751       1.246
# team[T.bragantino]:xg:venue[T.Home]        -0.2114      1.269     -0.167      0.868      -2.698       2.275
# team[T.corinthians]:xg:venue[T.Home]        0.5617      1.434      0.392      0.695      -2.250       3.373
# team[T.coritiba]:xg:venue[T.Home]           1.0117      1.594      0.635      0.526      -2.112       4.135
# team[T.cruzeiro]:xg:venue[T.Home]          -0.5217      1.500     -0.348      0.728      -3.462       2.419
# team[T.cuiaba]:xg:venue[T.Home]             0.1996      1.765      0.113      0.910      -3.260       3.659
# team[T.flamengo]:xg:venue[T.Home]          -0.3074      1.230     -0.250      0.803      -2.718       2.103
# team[T.fluminense]:xg:venue[T.Home]        -0.6704      1.180     -0.568      0.570      -2.983       1.642
# team[T.fortaleza]:xg:venue[T.Home]         -0.5577      1.205     -0.463      0.643      -2.919       1.804
# team[T.goias]:xg:venue[T.Home]              0.1816      1.344      0.135      0.893      -2.454       2.817
# team[T.gremio]:xg:venue[T.Home]             0.1610      1.177      0.137      0.891      -2.147       2.469
# team[T.internacional]:xg:venue[T.Home]     -1.5376      1.645     -0.935      0.350      -4.761       1.686
# team[T.palmeiras]:xg:venue[T.Home]         -1.0371      1.223     -0.848      0.396      -3.434       1.360
# team[T.santos]:xg:venue[T.Home]             0.0849      1.315      0.065      0.949      -2.493       2.662
# team[T.sao_paulo]:xg:venue[T.Home]         -0.4324      1.511     -0.286      0.775      -3.394       2.529
# team[T.vasco_da_gama]:xg:venue[T.Home]     -0.5131      1.377     -0.373      0.709      -3.211       2.185
# ===========================================================================================================

# %%
pred = model.predict_scores(test, tabela)

# %%
pred, score = model.accuracy_score(pred)

# %%
score
# Out:
# 0.5102040816326531

# %%
pred.head()
# Out:
#      wk  xg_casa  xg_fora       home  gols_casa  gols_fora            away  \
# 240  25      1.9      1.5  fortaleza        1.0        1.0          gremio
# 241  25      1.4      0.5   flamengo        1.0        0.0           bahia
# 242  25      1.2      0.2     cuiaba        3.0        0.0      fluminense
# 243  25      2.3      0.2  sao_paulo        2.0        1.0     corinthians
# 244  25      0.5      0.9   coritiba        2.0        0.0  ath_paranaense
#
#      vit_casa    empate  vit_fora resultado
# 240  0.354924  0.289982  0.353082  fracasso
# 241  0.699961  0.222443  0.070342    acerto
# 242  0.492291  0.286766  0.218491    acerto
# 243  0.509146  0.267492  0.219314    acerto
# 244  0.173123  0.273834  0.549660  fracasso
