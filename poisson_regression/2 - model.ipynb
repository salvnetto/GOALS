# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

from scipy import stats

# %%
league = {'brasileirao_a': ['Brasileirao'],
          'premier_league': ['Premier_League'],}


liga = league['brasileirao_a'][0]

# %%
historico = pd.read_excel(f'../datasets/{liga}/match_history/all_games/historico-2015a2023.xlsx')
rodadas = pd.read_excel(f'../datasets/{liga}/rounds/all_rounds/rodadas.xlsx')
tabela = pd.read_excel(f'../datasets/{liga}/standings/all_standings/season-2023/tabela-rodada29.xlsx')
#tabela = pd.read_excel(f'../datasets/{liga}/standings/all_standings/season-2023/tabela-rodada10.xlsx')

# %%
historico = historico[historico['season'] == 2023]

# %%
train = historico[historico['date'] < '2023-10-01'].dropna()
test = rodadas[rodadas['wk'] > 24].dropna()

#train = historico[historico['date'] < '2023-09-15'].dropna()
#test = rodadas[rodadas['wk'] > 4].dropna()

# %%
class Modelagem:
  # Fit no modelo
  def __init__(self, formula, data, max_goals= 5, output= None):
    self.modelo = smf.glm(formula= formula, data= data, family= sm.families.Poisson()).fit()
    #self.modelo = smf.glm(formula= formula, data= data, family= sm.families.NegativeBinomial()).fit()
    self.max_goals = max_goals
    if output is not None:
      print(self.modelo.summary())

  # Gerar Lambda
  def lambd(self, team, opponent, venue, stat, fator_casa= None):
    if fator_casa is True:
      string = 'casa' if venue == 'Home' else 'fora'
    else:
      string = 'total'

    data = {
        'team': team,
        'opponent': opponent,
        'venue': venue,
        'xg': float(stat[f'xg_{string}']),
        'xga': float(stat[f'xga_{string}']),
        'poss': float(stat[f'poss_{string}']),
        'sot': float(stat[f'sot_{string}']),
        'sh': float(stat[f'sh_{string}']),
        'time_diff': 1
    }
    return self.modelo.predict(pd.DataFrame(data, index=[0])).values[0]

  # Matriz de gols
  def matrix(self, lambda_x, lambda_y):
    prob_x = [stats.poisson.pmf(i, lambda_x) for i in range(0, self.max_goals+1)]
    prob_y = [stats.poisson.pmf(i, lambda_y) for i in range(0, self.max_goals+1)]

    return np.outer(prob_x, prob_y)
  
  # Função Final de Previsao de rodadas
  def predict_scores(self, matches, stats):
    for index, match in matches.iterrows():
      lambda_x = self.lambd(match['home'], match['away'], 'Home', stats.loc[stats['squad'] == match['home']], fator_casa= True)
      lambda_y = self.lambd(match['away'], match['home'], 'Away', stats.loc[stats['squad'] == match['away']], fator_casa= True)
      matrix_scores = self.matrix(lambda_x, lambda_y)
      
      matches.loc[index, 'vit_casa'] = np.sum(np.tril(matrix_scores, -1))
      matches.loc[index, 'empate'] = np.sum(np.diag(matrix_scores))
      matches.loc[index, 'vit_fora'] = np.sum(np.triu(matrix_scores, 1))
    
    return matches[['wk','xg_casa','xg_fora','home','gols_casa','gols_fora','away','vit_casa','empate','vit_fora']]
  
  # Teste acuracia
  def accuracy_score(self, matches):
    for index, match in matches.iterrows():
      #Gols
      if match['gols_casa'] > match['gols_fora']:
        matches.loc[index, 'resultado1'] = 'casa'
      elif match['gols_fora'] > match['gols_casa']:
        matches.loc[index, 'resultado1'] = 'fora'
      else:
        matches.loc[index, 'resultado1'] = 'empate'
      
      #Probabilidade
      if match['vit_casa'] > match['vit_fora'] and match['vit_casa'] > match['empate']:
        matches.loc[index, 'resultado2'] = 'casa'
      elif match['vit_fora'] > match['vit_casa'] and match['vit_fora'] > match['empate']:
        matches.loc[index, 'resultado2'] = 'fora'
      else:
        matches.loc[index, 'resultado2'] = 'empate'

    #Conclusao
    for index, match in matches.iterrows():
      if match['resultado1'] == match['resultado2']:
        matches.loc[index, 'resultado'] = 'acerto'
      else:
        matches.loc[index, 'resultado'] = 'fracasso'

    matches = matches.drop(['resultado1', 'resultado2'], axis= 1)
    score = matches['resultado'].value_counts()['acerto']/len(matches['resultado'])

    return matches, score

# %%
train.columns
# Out:
# Index(['date', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'sh', 'sot', 'season', 'team', 'days',
#        'time_diff'],
#       dtype='object')

# %%
#model = Modelagem(formula= 'gf ~ team*venue*poss*xg*sh + time_diff + opponent', data= train) #
model = Modelagem(formula= 'gf ~ team*xg*venue + opponent', data= train, output= True) #
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                     gf   No. Observations:                 3618
# Model:                            GLM   Df Residuals:                     3484
# Model Family:                 Poisson   Df Model:                          133
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4795.8
# Date:                Thu, 09 Nov 2023   Deviance:                       3612.4
# Time:                        13:55:59   Pearson chi2:                 3.08e+03
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.1452
# Covariance Type:            nonrobust
# =================================================================================================================
#                                                     coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                        -2.3015      0.967     -2.381      0.017      -4.196      -0.407
# team[T.ath_paranaense]                            1.9311      0.996      1.938      0.053      -0.022       3.884
# team[T.atl_goianiense]                            2.3752      0.994      2.389      0.017       0.426       4.324
# team[T.atl_mineiro]                               2.0894      1.161      1.800      0.072      -0.185       4.364
# team[T.avai]                                      1.2943      1.625      0.796      0.426      -1.891       4.480
# team[T.bahia]                                     2.2704      0.974      2.332      0.020       0.362       4.179
# team[T.botafogo_rj]                               2.0019      1.121      1.785      0.074      -0.196       4.200
# team[T.bragantino]                                1.4507      1.217      1.192      0.233      -0.935       3.837
# team[T.ceara]                                     1.6375      1.046      1.565      0.118      -0.413       3.688
# team[T.chapecoense]                              -0.2789      2.509     -0.111      0.911      -5.196       4.638
# team[T.corinthians]                               1.7248      1.135      1.519      0.129      -0.500       3.950
# team[T.coritiba]                                  2.2886      1.111      2.060      0.039       0.111       4.466
# team[T.cruzeiro]                                  0.7053      1.438      0.490      0.624      -2.114       3.524
# team[T.csa]                                      -2.2726      3.809     -0.597      0.551      -9.738       5.193
# team[T.cuiaba]                                    2.7978      1.313      2.131      0.033       0.224       5.372
# team[T.figueirense]                            7.327e-14   4.33e-14      1.691      0.091   -1.16e-14    1.58e-13
# team[T.flamengo]                                  2.8219      0.968      2.916      0.004       0.925       4.718
# team[T.fluminense]                                1.8415      1.030      1.788      0.074      -0.177       3.860
# team[T.fortaleza]                                 2.1004      1.074      1.955      0.051      -0.005       4.206
# team[T.goias]                                     2.5622      1.036      2.473      0.013       0.532       4.593
# team[T.gremio]                                    1.7241      1.052      1.639      0.101      -0.337       3.786
# team[T.figueirense]:xg_total:venue[T.Home]             0          0        nan        nan           0           0
# team[T.flamengo]:xg_total:venue[T.Home]           2.3218      0.972      2.389      0.017       0.417       4.227
# team[T.fluminense]:xg_total:venue[T.Home]         0.7147      1.034      0.691      0.490      -1.313       2.742
# team[T.fortaleza]:xg_total:venue[T.Home]          1.8355      1.034      1.776      0.076      -0.191       3.862
# team[T.goias]:xg_total:venue[T.Home]              1.6553      1.010      1.638      0.101      -0.325       3.636
# team[T.gremio]:xg_total:venue[T.Home]             1.0712      0.985      1.088      0.277      -0.858       3.001
# team[T.internacional]:xg_total:venue[T.Home]      1.1131      1.199      0.928      0.353      -1.237       3.463
# team[T.joinville]:xg_total:venue[T.Home]               0          0        nan        nan           0           0
# team[T.juventude]:xg_total:venue[T.Home]         -0.3160      1.950     -0.162      0.871      -4.138       3.506
# team[T.palmeiras]:xg_total:venue[T.Home]          1.0944      1.007      1.087      0.277      -0.879       3.068
# team[T.parana]:xg_total:venue[T.Home]                  0          0        nan        nan           0           0
# team[T.ponte_preta]:xg_total:venue[T.Home]             0          0        nan        nan           0           0
# team[T.santa_cruz]:xg_total:venue[T.Home]              0          0        nan        nan           0           0
# team[T.santos]:xg_total:venue[T.Home]             1.7422      1.094      1.592      0.111      -0.402       3.886
# team[T.sao_paulo]:xg_total:venue[T.Home]          2.6465      1.002      2.640      0.008       0.682       4.611
# team[T.sport_recife]:xg_total:venue[T.Home]       1.5969      1.596      1.001      0.317      -1.531       4.725
# team[T.vasco_da_gama]:xg_total:venue[T.Home]      1.4750      1.087      1.357      0.175      -0.655       3.605
# team[T.vitoria]:xg_total:venue[T.Home]                 0          0        nan        nan           0           0
# =================================================================================================================

# %%
pred = model.predict_scores(test, tabela)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\ProgramData\miniconda3\Lib\site-packages\patsy\compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File c:\ProgramData\miniconda3\Lib\site-packages\patsy\eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'xg_total' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# File c:\ProgramData\miniconda3\Lib\site-packages\statsmodels\base\model.py:1104, in Results._transform_predict_exog(self, exog, transform)
#    1103 try:
# -> 1104     exog = dmatrix(design_info, exog, return_type="dataframe")
#    1105 except Exception as exc:
#
# File c:\ProgramData\miniconda3\Lib\site-packages\patsy\highlevel.py:290, in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     289 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 290 (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     291                                   NA_action, return_type)
#     292 if lhs.shape[1] != 0:
#
# File c:\ProgramData\miniconda3\Lib\site-packages\patsy\highlevel.py:167, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     166 if design_infos is not None:
# --> 167     return build_design_matrices(design_infos, data,
#     168                                  NA_action=NA_action,
#     169                                  return_type=return_type)
#     170 else:
#     171     # No builders, but maybe we can still get matrices
#
# File c:\ProgramData\miniconda3\Lib\site-packages\patsy\build.py:888, in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     887 if factor_info not in factor_info_to_values:
# --> 888     value, is_NA = _eval_factor(factor_info, data, NA_action)
#     889     factor_info_to_isNAs[factor_info] = is_NA
#
# File c:\ProgramData\miniconda3\Lib\site-packages\patsy\build.py:63, in _eval_factor(factor_info, data, NA_action)
#      62 factor = factor_info.factor
# ---> 63 result = factor.eval(factor_info.state, data)
#      64 # Returns either a 2d ndarray, or a DataFrame, plus is_NA mask
#
# File c:\ProgramData\miniconda3\Lib\site-packages\patsy\eval.py:568, in EvalFactor.eval(self, memorize_state, data)
#     567 def eval(self, memorize_state, data):
# --> 568     return self._eval(memorize_state["eval_code"],
#     569                       memorize_state,
#     570                       data)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\patsy\eval.py:551, in EvalFactor._eval(self, code, memorize_state, data)
#     550 inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 551 return call_and_wrap_exc("Error evaluating factor",
#     552                          self,
#     553                          memorize_state["eval_env"].eval,
#     554                          code,
#     555                          inner_namespace=inner_namespace)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\patsy\compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      42     # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43     exec("raise new_exc from e")
#      44 else:
#      45     # In python 2, we just let the original exception escape -- better
#      46     # than destroying the traceback. But if it's a PatsyError, we can
#      47     # at least set the origin properly.
#
# File <string>:1
#
# PatsyError: Error evaluating factor: NameError: name 'xg_total' is not defined
#     gf ~ team*xg_total*venue + opponent
#               ^^^^^^^^
#
# During handling of the above exception, another exception occurred:
#
# PatsyError                                Traceback (most recent call last)
# g:\Meu Drive\Bet\poisson_regression\2 - model.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> pred = model.predict_scores(test, tabela)
#
# g:\Meu Drive\Bet\poisson_regression\2 - model.ipynb Cell 10 line 4
#      <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=37'>38</a> def predict_scores(self, matches, stats):
#      <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=38'>39</a>   for index, match in matches.iterrows():
# ---> <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=39'>40</a>     lambda_x = self.lambd(match['home'], match['away'], 'Home', stats.loc[stats['squad'] == match['home']], fator_casa= True)
#      <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=40'>41</a>     lambda_y = self.lambd(match['away'], match['home'], 'Away', stats.loc[stats['squad'] == match['away']], fator_casa= True)
#      <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=41'>42</a>     matrix_scores = self.matrix(lambda_x, lambda_y)
#
# g:\Meu Drive\Bet\poisson_regression\2 - model.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a>   string = 'total'
#      <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a> data = {
#      <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=17'>18</a>     'team': team,
#      <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a>     'opponent': opponent,
#    (...)
#      <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=25'>26</a>     'time_diff': 1
#      <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=26'>27</a> }
# ---> <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Bet/poisson_regression/2%20-%20model.ipynb#X12sZmlsZQ%3D%3D?line=27'>28</a> return self.modelo.predict(pd.DataFrame(data, index=[0])).values[0]
#
# File c:\ProgramData\miniconda3\Lib\site-packages\statsmodels\base\model.py:1173, in Results.predict(self, exog, transform, *args, **kwargs)
#    1128 def predict(self, exog=None, transform=True, *args, **kwargs):
#    1129     """
#    1130     Call self.model.predict with self.params as the first argument.
#    1131
#    (...)
#    1171     returned prediction.
#    1172     """
# -> 1173     exog, exog_index = self._transform_predict_exog(exog,
#    1174                                                     transform=transform)
#    1176     predict_results = self.model.predict(self.params, exog, *args,
#    1177                                          **kwargs)
#    1179     if exog_index is not None and not hasattr(predict_results,
#    1180                                               'predicted_values'):
#
# File c:\ProgramData\miniconda3\Lib\site-packages\statsmodels\base\model.py:1111, in Results._transform_predict_exog(self, exog, transform)
#    1105 except Exception as exc:
#    1106     msg = ('predict requires that you use a DataFrame when '
#    1107            'predicting from a model\nthat was created using the '
#    1108            'formula api.'
#    1109            '\n\nThe original error message returned by patsy is:\n'
#    1110            '{0}'.format(str(str(exc))))
# -> 1111     raise exc.__class__(msg)
#    1112 if orig_exog_len > len(exog) and not is_dict:
#    1113     if exog_index is None:
#
# PatsyError: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'xg_total' is not defined
#     gf ~ team*xg_total*venue + opponent
#               ^^^^^^^^

# %%
pred, score = model.accuracy_score(pred)

# %%
score
# Out:
# 0.5102040816326531

# %%
pred.head()
# Out:
#      wk  xg_casa  xg_fora       home  gols_casa  gols_fora            away  \
# 240  25      1.9      1.5  fortaleza        1.0        1.0          gremio
# 241  25      1.4      0.5   flamengo        1.0        0.0           bahia
# 242  25      1.2      0.2     cuiaba        3.0        0.0      fluminense
# 243  25      2.3      0.2  sao_paulo        2.0        1.0     corinthians
# 244  25      0.5      0.9   coritiba        2.0        0.0  ath_paranaense
#
#      vit_casa    empate  vit_fora resultado
# 240  0.354924  0.289982  0.353082  fracasso
# 241  0.699961  0.222443  0.070342    acerto
# 242  0.492291  0.286766  0.218491    acerto
# 243  0.509146  0.267492  0.219314    acerto
# 244  0.173123  0.273834  0.549660  fracasso
